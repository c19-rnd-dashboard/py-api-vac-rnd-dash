# %%
from api.utils.transform.products import milestone_transformer
from api.utils.loader import load
# Out:
# [2020-06-09 17:33:29,987] INFO in app: Database functionality initialized.  Click commands available.
# Instance setup.py found at:  /home/vbrandon/Bin/py-api-vac-rnd-dash/instance/setup.py
# Setting environment for testing local development

# %%
filepath = 'https://raw.githubusercontent.com/c19-rnd-dashboard/py-api-vac-rnd-dash/master/data/vaccines/vaccineworkfile4.csv'
data = load(filepath, loader="unfiltered_csv")
data.head()
# Out:
# [2020-06-09 17:33:30,900] INFO in loaders: Checking URL https://raw.githubusercontent.com/c19-rnd-dashboard/py-api-vac-rnd-dash/master/data/vaccines/vaccineworkfile4.csv.  Getting status 200
# [2020-06-09 17:33:30,901] INFO in loaders: Checking Extension csv.
# [2020-06-09 17:33:30,902] INFO in loaders: IsFile tests: run: False-True
# [2020-06-09 17:33:30,903] INFO in loaders: Checking Extension csv.
# [2020-06-09 17:33:30,905] INFO in loaders: <load_unfiltered_csv> Starting .csv data inference
# <filetype csv>
#   ID Source?                           Product Name - Preferred  \
# 0  1      No                                          mRNA-1273
# 1  1     Yes  https://www.nih.gov/news-events/news-releases/...
# 2  2      No                                    Novavax Vaccine
# 3  2     Yes  https://investors.emergentbiosolutions.com/new...
# 4  3      No                                             BNT162
#
#                              Product Name - Chemical Product Name - Brand  \
# 0                                                               mRNA-1273
# 1  https://www.nih.gov/news-events/news-releases/...
# 2                                                         Novavax Vaccine
# 3  https://investors.emergentbiosolutions.com/new...
# 4                                                                 BNT-162
#
#                                              Sponsor  \
# 0  Moderna; National Institute of Allergy and Inf...
# 1  https://www.nih.gov/news-events/news-releases/...
# 2           Novavax Inc.; Emergent BioSolutions Inc.
# 3  https://investors.emergentbiosolutions.com/new...
# 4                           Pfizer Inc.; BioNTech SE
#
#                                    Intervention Type  \
# 0                             Vaccine - Prophylactic
# 1  https://www.nih.gov/news-events/news-releases/...
# 2                             Vaccine - Prophylactic
# 3  https://investors.emergentbiosolutions.com/new...
# 4                             Vaccine - Prophylactic
#
#                                           Indication  \
# 0                                           COVID-19
# 1  https://www.nih.gov/news-events/news-releases/...
# 2                                           COVID-19
# 3  https://ir.novavax.com/news-releases/news-rele...
# 4                                           COVID-19
#
#                                        Molecule Type  \
# 0              Nucleic acid based therapies/vaccines
# 1  https://www.nih.gov/news-events/news-releases/...
# 2                                   Subunit Vaccines
# 3  https://ir.novavax.com/news-releases/news-rele...
# 4              Nucleic acid based therapies/vaccines
#
#                                 Therapeutic Approach  ...  \
# 0                                            Vaccine  ...
# 1  https://www.nih.gov/news-events/news-releases/...  ...
# 2                                              Other  ...
# 3                                                     ...
# 4                                              Other  ...
#
#                          How to participate   Data Entry 1 Owner  \
# 0  https://corona.kpwashingtonresearch.org/                 Mats
# 1  https://corona.kpwashingtonresearch.org/
# 2                                                          James
# 3
# 4                                                          James
#
#   Date Entry 1 Performed Data Entry 2 Owner Date Entry 2 Performed  \
# 0              3/27/2020
# 1
# 2               4/2/2020
# 3
# 4               4/2/2020
#
#   Data Entry Update Owner Date Update Performed   Last Updated
# 0                                                    3/27/2020
# 1
# 2                                                     4/2/2020
# 3
# 4                                                     4/2/2020
#
# [5 rows x 49 columns]

# %%
tdata = milestone_transformer(data)
# Out:
# /home/vbrandon/miniconda3/envs/covidbe/lib/python3.7/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
data.iloc[0]
# Out:
# ID                                                                                               1
# Source?                                                                                         No
# Product Name - Preferred                                                                 mRNA-1273
# Product Name - Chemical
# Product Name - Brand                                                                     mRNA-1273
# Sponsor                                          Moderna; National Institute of Allergy and Inf...
# Intervention Type                                                           Vaccine - Prophylactic
# Indication                                                                                COVID-19
# Molecule Type                                                Nucleic acid based therapies/vaccines
# Therapeutic Approach                                                                       Vaccine
# New/Repurposed                                                                                 New
# Funding/Manufacturing/Research/Other Partners                                                 CEPI
# Country                                                                              United States
# Status                                                                                     Ongoing
# Notes                                                                           mRNA-based vaccine
#
# Current Stage                                                                              Phase 1
#
# Discovery Started                                                                        1/11/2020
# Pre-Clinical Studies Started                                                               SKIPPED
# Lead Selection Finalized                                                                 1/13/2020
# Clinical Batch Finalized                                                                  2/7/2020
# IND or Equivalent Approval Finalized                                                      3/4/2020
# Phase 1 Started                                                                          3/16/2020
# Phase 2 Started
# Phase 3 Started
# NDA or equivalent Approval Finalized
#
#
# Phase                                                                                            1
# Condition or Disease                                                                      COVID-19
# Number of Participants                                                                          45
# Accepts Healthy Subjects
# # of Sites                                                                                       2
# Sites Locations                                  Kaiser Permanente Washington Health Research I...
# Study Start Date                                                                         3/16/2020
# Primary Completion DAte                                                                   6/1/2021
# Study Completion Date                                                                     6/1/2021
# CTG Identifier                                                                         NCT04283461
# How to participate                                        https://corona.kpwashingtonresearch.org/
#
# Data Entry 1 Owner                                                                            Mats
# Date Entry 1 Performed                                                                   3/27/2020
# Data Entry 2 Owner
# Date Entry 2 Performed
# Data Entry Update Owner
# Date Update Performed
#
# Last Updated                                                                             3/27/2020
# Name: 0, dtype: object

# %%
tdata[tdata.product_id==1]
# Out:
#       product_id                  name       date  milestone_id  \
# 0              1  pre_clinical_studies    SKIPPED            12
# 566            1        lead_selection  1/13/2020            13
# 1132           1        clinical_batch   2/7/2020            21
# 1698           1                   ind   3/4/2020            31
# 2264           1               phase_1  3/16/2020            41
# 4528           1             discovery  1/11/2020            11
#
#                   category     status  id_completed  link_id
# 0             pre-clinical    SKIPPED             0        0
# 566           pre-clinical  COMPLETED            13      566
# 1132         manufacturing  COMPLETED            21     1132
# 1698            regulatory  COMPLETED            31     1698
# 2264  clinical_development  COMPLETED            41     2264
# 4528          pre-clinical  COMPLETED            11     4528
